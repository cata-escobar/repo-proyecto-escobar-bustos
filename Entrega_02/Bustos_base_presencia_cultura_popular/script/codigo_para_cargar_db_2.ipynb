# %%
import pandas as pd

# Cargar el archivo CSV en un DataFrame de Pandas
archivo_csv = 'base presencia en la cultura popular limpio.csv'
df = pd.read_csv(archivo_csv, sep=';')

# Visualizar las primeras 5 filas de la base de datos
df.head()
# Out:
#   appearance_id artista_proyecto        nombre_cancion  aparicion        tipo  \
# 0        BLU001             Blur               Badhead       2013       Serie
# 1        BLU002             Blur             Beetlebum       2008  Videojuego
# 2        BLU003             Blur             Beetlebum       2015       Serie
# 3        BLU004             Blur             Beetlebum       1997       Serie
# 4        BLU005             Blur  Brothers and Sisters       2011       Serie
#
#         titulo_obra temporada_episodio       pais_obra  lanzamiento_cancion
# 0  My Mad Fat Diary              S1/E4     Reino Unido                 1994
# 1        Rock Band                 NaN  Estados Unidos                 1997
# 2  My Mad Fat Diary              S3/E2     Reino Unido                 1997
# 3             Daria              S1/E9  Estados Unidos                 1997
# 4     Top Gear (UK)             S17/E5     Reino Unido                 2003
