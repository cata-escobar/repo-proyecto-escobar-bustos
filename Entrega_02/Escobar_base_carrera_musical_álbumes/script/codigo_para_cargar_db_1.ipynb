# %%
import pandas as pd

# Cargar el archivo CSV en un DataFrame de Pandas
df = pd.read_csv('base carrera musical (álbumes) LIMPIO.csv', sep=';')

# Visualizar las primeras 5 filas de la base de datos
df.head()
# Out:
#   album_id artista_proyecto tipo_discografia  \
# 0  BLU_001             Blur            Album
# 1  BLU_002             Blur            Album
# 2  OAS_001            Oasis            Album
# 3  OAS_002            Oasis       Live album
# 4  OAS_003            Oasis   Live broadcast
#
#                                         nombre_album  año_lanzamiento UK_peak  \
# 0                                            Leisure             1991       7
# 1                             Modern Life Is Rubbish             1993      15
# 2                                   Definitely Maybe             1994       1
# 3  1994-04-24: Glastonbury Festival of Contempora...             1994       -
# 4                       Oasis - Evening Session 1993             1994       -
#
#   semanas_chart_UK US_peak semanas_chart_US certificacion_BPI
# 0               22       -                -               Oro
# 1               19       -                -               Oro
# ...
